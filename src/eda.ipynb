# %%
import pandas as pd

# %%
df = pd.read_excel(r'/Volumes/T7/Back-up/webs/data_engineer_projects/etl_xls_to_postgress/src/data/financial_sample.xlsx')
df.tail(4)
# Out:
#               Segment                   Country   Product Discount Band
# 696    Small Business                    Mexico  Amarilla          High  \
# 697        Government                    Mexico   Montana          High
# 698        Government                    Canada     Paseo          High
# 699  Channel Partners  United States of America       VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts
# 696       546.0                  260         300     163800.0   24570.00  \
# 697      1368.0                    5           7       9576.0    1436.40
# 698       723.0                   10           7       5061.0     759.15
# 699      1806.0                  250          12      21672.0    3250.80
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year
# 696  139230.00  136500.0   2730.00 2014-10-01            10    October  2014
# 697    8139.60    6840.0   1299.60 2014-02-01             2   February  2014
# ...

# %%
df_clean = df[['Segment', 'Country', 'Product', 'Gross Sales', 'Discounts',
       ' Sales', 'COGS', 'Profit', 'Date']].copy()
df_clean.head()
# Out:
#       Segment  Country    Product  Gross Sales  Discounts    Sales     COGS
# 0  Government   Canada  Carretera      32370.0        0.0  32370.0  16185.0  \
# 1  Government  Germany  Carretera      26420.0        0.0  26420.0  13210.0
# 2   Midmarket   France  Carretera      32670.0        0.0  32670.0  21780.0
# 3   Midmarket  Germany  Carretera      13320.0        0.0  13320.0   8880.0
# 4   Midmarket   Mexico  Carretera      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date
# 0  16185.0 2014-01-01
# 1  13210.0 2014-01-01
# 2  10890.0 2014-06-01
# 3   4440.0 2014-06-01
# 4  12350.0 2014-06-01

# %%
df_clean.groupby(['Country']).count()
# Out:
#                           Segment  Product  Gross Sales  Discounts   Sales
# Country
# Canada                        140      140          140        140     140  \
# France                        140      140          140        140     140
# Germany                       140      140          140        140     140
# Mexico                        140      140          140        140     140
# United States of America      140      140          140        140     140
#
#                           COGS  Profit  Date
# Country
# Canada                     140     140   140
# France                     140     140   140
# Germany                    140     140   140
# Mexico                     140     140   140
# United States of America   140     140   140

# %%
# Transform
ct = ['United States of America', 'Mexico', 'Canada']
df_clean = df_clean[df_clean['Country'].isin(ct)]
df_clean.groupby(['Country']).count()
# Out:
#                           Segment  Product  Gross Sales  Discounts   Sales
# Country
# Canada                        140      140          140        140     140  \
# Mexico                        140      140          140        140     140
# United States of America      140      140          140        140     140
#
#                           COGS  Profit  Date
# Country
# Canada                     140     140   140
# Mexico                     140     140   140
# United States of America   140     140   140
